# %%
count=0
a=input("\n1) What's the tallest building in the World:").lower()
if a=="burj khalifa":
        count+=1   

b=input("\n2) What's the largest living organism:").lower()
if a=="blue whale":
         count+=1

a=input("\n3) What's the deepest ocean in the World:").lower()
if a=="pacific ocean":
    count+=1
     
a=input("\n4) What's the smallest city in the world:").lower()
if a=="vatican city":
         count+=1

a=input("\n5) What's the most populated city in the world:").lower()
if a=="china":
        count+=1

    
print("\nYour Final Csore:",count,"/ 5")
# Out:
# 1) What's the tallest building in the World:dsds
#
# 2) What's the largest living organism:blue whale
#
# 3) What's the deepest ocean in the World:pacific ocean
#
# 4) What's the smallest city in the world:sdsd
#
# 5) What's the most populated city in the world:dss
#
# Your Final Csore: 1 / 5

# %%
import random
tries=0
top_of_range=input("Enter a number: ")

if top_of_range.isdigit():
    top_of_range = int(top_of_range)
    
    if(top_of_range <=0):
        print("Enter non zero element:")
else:
    print("Enter a number please!")
    
    
random_number=random.randint(0,top_of_range)


while True:
    tries+=1
    user_guess=input("Enter your guess: ")
    if user_guess.isdigit():
     user_guess = int(user_guess)
    
    
    else:
     print("Enter a number please!")
     continue
    
    if user_guess==random_number:
        print("You got it")
        break
        
    else:
        if user_guess>random_number:
            print("Your guess was above the number:")
        else:
            print("Your guess was below the number:")
        
     
print("No. of tries to guess: "+str(tries))
# Out:
# Enter a number: 4
# Enter your guess: 1
# Your guess was below the number:
# Enter your guess: 3
# Your guess was above the number:
# Enter your guess: 2
# You got it
# No. of tries to guess: 3

# %%
user_wins=0
computer_wins=0
ties=0



options=['rock','paper','scissors']
while True:
 user_input=input("Enter your pick or PRESS 'q' to quit ").lower()

 if user_input=='q':
    break
 if user_input not in options:
    continue
     
   

   
        

        
 random_number=random.randint(0,2)

 computer_input=options[random_number]
 print("Computer picked ",computer_input)

 #rock:0
 #paper:1
 #scissors:2

 if computer_input==options[0]:
    if user_input==options[0]:
        print("Tie")
        ties+=1
    elif user_input==options[1]:
        print("Win")
        user_wins+=1
    else:
        print("Lose")
        computer_wins+=1
        
 if computer_input==options[1]:
    if user_input==options[0]:
        print("Lose")
        computer_wins+=1
    elif user_input==options[1]:
        print("Tie")
        ties+=1
        
    else:
        print("Win")
        user_wins+=1
        
        
 if computer_input==options[2]:
    if user_input==options[0]:
        print("Win")
        user_wins+=1
    elif user_input==options[1]:
        print("Lose")
        computer_wins+=1
        
    else:
        print("Tie")
        ties+=1
        
        
print("Your wins:",user_wins)
print("Computer wins:",computer_wins)
print("Ties: ",ties)
# Out:
# Enter your pick or PRESS 'q' to quit paper
# Computer picked  scissors
# Lose
# Enter your pick or PRESS 'q' to quit rock
# Computer picked  rock
# Tie
# Enter your pick or PRESS 'q' to quit scissors
# Computer picked  scissors
# Tie
# Enter your pick or PRESS 'q' to quit paper
# Computer picked  rock
# Win
# Enter your pick or PRESS 'q' to quit q
# Your wins: 1
# Computer wins: 1
# Ties:  2

# %%
master_pwd=input("What's the master Password?:")



def add():
    name=input("Account name: ")
    pwd=input("Password: ")
    
    with open('password.txt','a') as f:
        f.write("User:",name+"\n","password: ",pwd+"\n")
        
        
def view():
    with open('password.txt','r') as f:
        for lines in f.readlines():
            print(lines.rstrip())

while True:
    mode=input("Would like to add a new one or view an existing one?! Or press'q' to quit!").upper()

    if mode=="Q":
        break
    
    elif mode=="ADD":
        add()

    elif mode=="VIEW":
        view()
    
    else:
            print("Invalid Mode")
            continue
